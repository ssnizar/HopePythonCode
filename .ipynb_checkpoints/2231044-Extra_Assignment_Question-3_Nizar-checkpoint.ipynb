# %%
num1=input("enter the value")
if (int(num1)==10):
    print("Value:" ,num1)
    print("Correct")
else:
    print("Not Correct")
# Out:
# enter the value 10
# Value: 10
# Correct

# %%
str1=input("enter the Passwor")
if (str1=="HOPE@123"):
    print("Your password is correct")
else:
    print("Not Correct")
# Out:
# enter the Passwor HOPE@123
# Your password is correct

# %%
age1=input("enter the Age")
print("age:",age1)
if (int(age1)<18):
    print("Children")
elif (int(age1)<40):    
    print("Adult")
elif (int(age1)<60):    
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# enter the Age 20
# age: 20
# Adult

# %%
num1=input("enter the number")
if (int(num1)>0):
    print("No. is Positive")
elif (int(num1)<0):
    print("Negative Number")
else:
    print("Zero")
# Out:
# enter the number 1
# No. is Positive

# %%
num1=input("enter a number to check")
if (int(num1)%5==0):
    print("No is divisible by 5")
else:
    print("No is not divisible by 5")
# Out:
# enter a number to check 22
# No is not divisible by 5

# %%
print("End")
# Out:
# End
