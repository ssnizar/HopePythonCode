# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=10
Num2=30
print("Num1=",Num1)
print("Num2=",Num2)
print("Add=",Num1+Num2)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
# 18.5 to 24.9  Healthy BMi,  25 to 29.9  overweight 30 or above obese or very overweight
bmi=float(input("Enter the BMI Index"))
if (bmi<18.4):
    print("Under Weight")
elif (bmi<=24.9):
    print("Healthy BMI")
elif (bmi<=29.9):
    print("OverWeight")
else:
    print("Very OverWeight")
# Out:
# Enter the BMI Index 34
# Very OverWeight
