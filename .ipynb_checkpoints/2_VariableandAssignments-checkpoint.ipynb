# %%
num1=10
num2=30
addnum=num1+num2
subnum=num1-num2
print("add")
print(addnum)
print("sub")
print(subnum)
# Out:
# add
# 40
# sub
# -20

# %%
num1=10
num2=20
addnum=num1+num2
print("Addition of two numbers")
print("The number1 : ",num1))
print("The number2 : ", num2)
print("The Answer : ", addnum)
# Out:
# Addition of two numbers
# The number1 :  10
# The number2 :  20
# The Answer :  30

# %%
num1=int(input("Enter the num1 : "))
num2=int(input("Enter the num2 : "))
addnumstr=num1+num2
print("The answer of string is : ", addnumstr)
addnum=int(num1) + num2
print("The answer number is " , addnum)
# Out:
# Enter the num1 :  10
# Enter the num2 :  20
# The answer of string is :  30
# The answer number is  30

# %%
str1='This is String'
str2="1215423423"
print(str1)
print(str2)
# Out:
# This is String
# 1215423423
