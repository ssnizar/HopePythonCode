# %%
#1.Find the error in the following Python code:
import math
#print(Math.sqrt(16))
print(math.sqrt(16))
#import role math. so we call math.sqrt
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:

def my_function(x):
    x += 5
    print(x)

x = 20
my_function(x)
#x is not declare inside function or as passing argument. it ask x value. so it shows unbound error cann not access value x+=5
# Out:
# 25

# %%
#3.x = 5
x = 5
if x == 10:
    print("x is 10")
# is comment statment so we assign in next line and also assignin ooperator need

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

# %%
#5.
def square(n):
    #n * n
    return n * n

print(square(4))
# there is no return value so it given none
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
#my_tuple[1] = 5
print(my_tuple[1])
#tuple collection can not change or assignafter creation . only we can call
# Out:
# 2

# %%
#7.
name = "Alice"
age = 25
#print("My name is %s and I am %d years old" % (name))
print(f"My name is {name} and I am {age} years old")
#we will provide dyanimic value with {} with f statement
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
#if a is b:
if a == b:
    print("Lists are equal")
# we use is only for object equeal. but value verifiecation we will use == operator 
# is operator does not return result.  == operator reurn value
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1,-1):
    print(i)
#i we need to provide -1 because range is 5 to 1
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
#print(student[name])
print(student["name"])
#dictionary key value pari, we need to call with quotes
# Out:
# John
