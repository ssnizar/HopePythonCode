# %%
from ClassAssignmentFinal import AssignmentFinal

# %%
AssignmentFinal.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
result=AssignmentFinal.oddEven()
print(result)
# Out:
# Enter the number: 55
# 55 is Odd Number

# %%
AssignmentFinal.Elegible("Male",21)
AssignmentFinal.Elegible("Female",18)
AssignmentFinal.Elegible("Male",20)
AssignmentFinal.Elegible("Female",17)
# Out:
# Your Gender: Male
# Your Age: 21
# ELIGIBLE
# Your Gender: Female
# Your Age: 18
# ELIGIBLE
# Your Gender: Male
# Your Age: 20
# NOT ELGIBLE
# Your Gender: Female
# Your Age: 17
# NOT ELGIBLE

# %%
AssignmentFinal.percentage(45,45,77,75,88)
AssignmentFinal.percentage(88,88,77,75,93)
# Out:
# Subject1= 45
# Subject1= 45
# Subject1= 77
# Subject1= 75
# Subject1= 88
# total : 330
# Percentage : 66.0
# Subject1= 88
# Subject1= 88
# Subject1= 77
# Subject1= 75
# Subject1= 93
# total : 421
# Percentage : 84.2

# %%
AssignmentFinal.triangle_area(34,32)
AssignmentFinal.triangle_perimeter(2,4,4)
# Out:
# base : 34
# height: 32
# Area formula : (Height * base)/2)
# Area of triangle 544.0
# base: 2
# side1: 4
# side2: 4
# Perimeter formula: base+side1+side2
# Perimeter of Triangle: 10
