# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)

#indent amd colon
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + int(b))
#conversiton from string to int
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    return a + b
#indent and coloan

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4,777]
print(numbers[4])
#not avilable 4 value
# Out:
# 777

# %%
#5.Find the error in the following Python code:
print("Hello, World!")
#no parantheses
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 10
#divided by zerio. so i changes as 10

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
name="the one"
print("Name: " + name + ", Age: " + str(age))
#name variable not declared and conversion error
# Out:
# Name: the one, Age: 25

# %%
#8.Find the error
#for i in range(1, 10, -1):
for i in range(10, 1, -1):
    print(i)
#range is asceindig order but reducte as -1, the right thins we increment 1 or will change the range
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
#if x = 5:
if x == 5:
    print("x is 5")
# here = is assgiement operator , we need to rectify we need to user ==

# %%
#10. Identify the error in the following function definition:

def greet(name):
    print("Hello, " + name)
# colon is not available
