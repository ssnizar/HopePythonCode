# %%
age=input("Enter the Age:")
if (int(age)>=18):
    print("Vote is eligible")
else:
    print("Vote is Not Elibile")
# Out:
# Enter the Age: 18
# Vote is eligible

# %%
list1=[45,23,65,878,121,454,7878,232]
largevalue=max(list1)
print(f"Larges value is {largevalue}")
# Out:
# Larges value is 7878

# %%
SalaryList=[34444,50100,49900,80000]
for i in SalaryList:
    if (i>50000):
        salinc= i * .10
        print(f"Salary {i} for increment {salinc}")
    else:
        print(f"Salary  {i}  No increment")
# Out:
# Salary  34444  No increment
# Salary 50100 for increment 5010.0
# Salary  49900  No increment
# Salary 80000 for increment 8000.0

# %%
GivenNo=[34,52,49,88]
for j in GivenNo:
    if ((j % 2 )==0):
        print(f"Given Number {j} is Even Number")
    else:
        print(f"Given Number {j} is Odd Number")
# Out:
# Given Number 34 is Even Number
# Given Number 52 is Even Number
# Given Number 49 is Odd Number
# Given Number 88 is Even Number

# %%
GivenStr = "This is String for Reverse"
rev = GivenStr[::-1]  
#slicing option
print(rev)
rstr=""
for istr in GivenStr:
	#print(istr)
	rstr=istr+rstr
	#print(rstr)
print(rstr)
# Out:
# esreveR rof gnirtS si sihT
# esreveR rof gnirtS si sihT

# %%
StudentSubject=["T","E","M","S","SS"]
StudentMarks1=[63,55,24,34,90]
found_positions = []
target = 40
for ival in range(len(StudentMarks1)):
    if StudentMarks1[ival] < target:
        found_positions.append(ival)
        #print(ival)
        
#print(found_positions) 
Total=len(found_positions)

if (Total==0):
    print("Student Passed")
else:
   print(f"Student Failed in {Total} subject")
# Out:
# Student Failed in 2 subject

# %%
TotalPurchseCustomerValue=[134,252,99,88,100]
for TotalAmount in TotalPurchseCustomerValue:
    if (TotalAmount >=100):
        Discount=TotalAmount *.20
        NetAmount=TotalAmount-Discount
        print(f"Given Discount {Discount} for Amount {TotalAmount} Now Net Amount is after discount {NetAmount}")
    else:
        print(f"No Discount for {TotalAmount}")
# Out:
# Given Discount 26.8 for Amount 134 Now Net Amount is after discount 107.2
# Given Discount 50.400000000000006 for Amount 252 Now Net Amount is after discount 201.6
# No Discount for 99
# No Discount for 88
# Given Discount 20.0 for Amount 100 Now Net Amount is after discount 80.0

# %%
AmountAvailable=[34444,501,9000,18000]
WithdrawAmount=10000
for AvaAmount in AmountAvailable:
    if (AvaAmount > WithdrawAmount):
        print("Eligible to Withdraw amount")
    else:
         print(f"Not Eligible to Withdraw amount available amount is {AvaAmount}")
# Out:
# Eligible to Withdraw amount
# Not Eligible to Withdraw amount available amount is 501
# Not Eligible to Withdraw amount available amount is 9000
# Eligible to Withdraw amount

# %%
leapyear=input("enter the leap year:")
last_two_digits = str(leapyear)[-2:]
#print(last_two_digits)

if ((int(leapyear) % 4) ==0 and last_two_digits!="00"):
    print(f"Leap Year {leapyear}")
elif ((int(leapyear) % 400 ==0 )):
    print(f"Leap Year {leapyear}")
else:
    print(f"Not Leap Year - {leapyear}")
# Out:
# enter the leap year: 1900
# 00
# Not Leap Year - 1900

# %%
list1=[22,33,11,66,35,90]
def evenonly(num):
    if ((num%2)==0):
        return num

for in2 in list1:
    thisn=evenonly(in2)
    if num.isdigit()
        print(thisn)
# Out:
#   Cell In[80], line 8
#     if num.isdigit()
#                     ^
# SyntaxError: expected ':'
